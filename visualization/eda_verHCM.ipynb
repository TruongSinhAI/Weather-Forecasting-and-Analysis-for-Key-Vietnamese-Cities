# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from datetime import datetime

# %%
path = 'E:\HaoDevAI\DAP391m_Project\datasets\HoChiMinh.csv'
df = pd.read_csv(path, parse_dates=['datetime'])
print(path,' loaded successfully. Shape:', df.shape)
# Out:
# E:\HaoDevAI\DAP391m_Project\datasets\HoChiMinh.csv  loaded successfully. Shape: (9149, 33)

# %%
cutoff_date = pd.Timestamp("2010-01-01")
df = df[df['datetime'] >= cutoff_date]
df.shape
# Out:
# (5496, 33)

# %%
df.head()
# Out:
#                        name   datetime  tempmax  tempmin  temp  feelslikemax  \
# 3653  Hồ Chí Minh, Việt Nam 2010-01-01     33.1     22.1  26.6          34.1
# 3654  Hồ Chí Minh, Việt Nam 2010-01-02     32.0     22.0  27.1          34.9
# 3655  Hồ Chí Minh, Việt Nam 2010-01-03     32.2     24.0  27.2          36.8
# 3656  Hồ Chí Minh, Việt Nam 2010-01-04     32.0     23.0  27.2          33.5
# 3657  Hồ Chí Minh, Việt Nam 2010-01-05     33.0     23.1  27.1          36.1
#
#       feelslikemin  feelslike   dew  humidity  ...  solarenergy  uvindex  \
# 3653          22.1       27.4  20.9      74.2  ...         18.9      8.0
# 3654          22.0       28.7  21.0      70.7  ...         20.1      8.0
# 3655          24.0       28.7  21.9      73.7  ...         20.0      8.0
# 3656          23.0       27.9  20.0      66.5  ...         20.9      8.0
# 3657          23.1       28.3  21.8      74.5  ...         20.9      8.0
#
#       severerisk   sunrise    sunset  moonphase        conditions  \
# 3653         NaN  06:11:28  17:41:46       0.50  Partially cloudy
# 3654         NaN  06:11:52  17:42:19       0.55  Partially cloudy
# 3655         NaN  06:12:15  17:42:51       0.58  Partially cloudy
# 3656         NaN  06:12:37  17:43:24       0.62  Partially cloudy
# 3657         NaN  06:12:58  17:43:57       0.65  Partially cloudy
#
#                             description               icon  \
# 3653  Partly cloudy throughout the day.  partly-cloudy-day
# 3654  Partly cloudy throughout the day.  partly-cloudy-day
# 3655  Partly cloudy throughout the day.  partly-cloudy-day
# 3656  Partly cloudy throughout the day.  partly-cloudy-day
# 3657  Partly cloudy throughout the day.  partly-cloudy-day
#
#                                stations
# 3653  ['48900099999', 'VVTS', 'remote']
# 3654            ['48900099999', 'VVTS']
# 3655            ['48900099999', 'VVTS']
# 3656            ['48900099999', 'VVTS']
# 3657            ['48900099999', 'VVTS']
#
# [5 rows x 33 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5496 entries, 3653 to 9148
# Data columns (total 33 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   name              5496 non-null   object
#  1   datetime          5496 non-null   datetime64[ns]
#  2   tempmax           5496 non-null   float64
#  3   tempmin           5496 non-null   float64
#  4   temp              5496 non-null   float64
#  5   feelslikemax      5496 non-null   float64
#  6   feelslikemin      5496 non-null   float64
#  7   feelslike         5496 non-null   float64
#  8   dew               5496 non-null   float64
#  9   humidity          5496 non-null   float64
#  10  precip            5496 non-null   float64
#  11  precipprob        5496 non-null   float64
#  12  precipcover       5496 non-null   float64
#  13  preciptype        3909 non-null   object
#  14  snow              3701 non-null   float64
#  15  snowdepth         3701 non-null   float64
#  16  windgust          3814 non-null   float64
#  17  windspeed         5496 non-null   float64
#  18  winddir           5496 non-null   float64
#  19  sealevelpressure  0 non-null      float64
#  20  cloudcover        5496 non-null   float64
#  21  visibility        5496 non-null   float64
#  22  solarradiation    5496 non-null   float64
#  23  solarenergy       5496 non-null   float64
#  24  uvindex           5496 non-null   float64
#  25  severerisk        413 non-null    float64
#  26  sunrise           5496 non-null   object
#  27  sunset            5496 non-null   object
#  28  moonphase         5496 non-null   float64
#  29  conditions        5496 non-null   object
#  30  description       5496 non-null   object
#  31  icon              5496 non-null   object
#  32  stations          5495 non-null   object
# dtypes: datetime64[ns](1), float64(24), object(8)
# memory usage: 1.4+ MB

# %%
df.describe()
# Out:
#                   datetime      tempmax      tempmin         temp  \
# count                 5496  5496.000000  5496.000000  5496.000000
# mean   2017-07-10 12:00:00    32.870906    24.675382    28.090975
# min    2010-01-01 00:00:00    23.100000     7.000000    22.100000
# 25%    2013-10-05 18:00:00    32.000000    24.000000    27.175000
# 50%    2017-07-10 12:00:00    33.000000    25.000000    28.100000
# 75%    2021-04-14 06:00:00    34.000000    26.000000    29.100000
# max    2025-01-17 00:00:00    39.000000    30.000000    33.000000
# std                    NaN     1.847575     1.783071     1.493935
#
#        feelslikemax  feelslikemin    feelslike          dew     humidity  \
# count   5496.000000   5496.000000  5496.000000  5496.000000  5496.000000
# mean      37.973763     25.195306    30.939520    23.304039    77.252420
# min       23.100000      5.100000    22.100000    12.300000    49.500000
# 25%       35.900000     24.000000    28.800000    22.200000    70.800000
# 50%       38.100000     25.000000    30.700000    23.900000    78.000000
# 75%       40.300000     26.000000    32.800000    24.800000    84.400000
# max       48.700000     40.000000    42.000000    27.900000    99.800000
# std        3.256378      2.884020     3.020335     2.169938     9.463665
#
#             precip  ...    windspeed      winddir  sealevelpressure  \
# count  5496.000000  ...  5496.000000  5496.000000               0.0
# mean      4.742413  ...    19.480841   181.538173               NaN
# min       0.000000  ...     7.200000     0.000000               NaN
# 25%       0.000000  ...    15.800000   124.100000               NaN
# 50%       0.700000  ...    18.400000   173.950000               NaN
# 75%       4.700000  ...    22.300000   248.225000               NaN
# max     227.200000  ...    50.000000   359.700000               NaN
# std      10.980253  ...     5.387818    81.172062               NaN
#
#         cloudcover   visibility  solarradiation  solarenergy      uvindex  \
# count  5496.000000  5496.000000     5496.000000  5496.000000  5496.000000
# mean     56.408242     9.708242      207.950036    17.956168     7.506004
# min       9.700000     5.200000        0.000000     0.000000     0.000000
# 25%      46.500000     9.200000      171.900000    14.800000     7.000000
# 50%      55.500000     9.900000      214.900000    18.600000     8.000000
# 75%      66.000000    10.300000      248.900000    21.500000     9.000000
# max     100.000000    76.600000      320.200000    27.800000    10.000000
# std      14.285112     1.816375       53.172553     4.596613     1.720180
#
#        severerisk    moonphase
# count  413.000000  5496.000000
# mean    34.067797     0.484369
# min     10.000000     0.000000
# 25%     30.000000     0.250000
# 50%     30.000000     0.500000
# 75%     60.000000     0.750000
# max     75.000000     0.980000
# std     17.482037     0.288696
#
# [8 rows x 25 columns]

# %%
df.isnull().sum()
# Out:
# name                   0
# datetime               0
# tempmax                0
# tempmin                0
# temp                   0
# feelslikemax           0
# feelslikemin           0
# feelslike              0
# dew                    0
# humidity               0
# precip                 0
# precipprob             0
# precipcover            0
# preciptype          1587
# snow                1795
# snowdepth           1795
# windgust            1682
# windspeed              0
# winddir                0
# sealevelpressure    5496
# cloudcover             0
# visibility             0
# solarradiation         0
# solarenergy            0
# uvindex                0
# severerisk          5083
# sunrise                0
# sunset                 0
# moonphase              0
# conditions             0
# description            0
# icon                   0
# stations               1
# dtype: int64

# %%
df[['snow','snowdepth','windgust','severerisk','precip']].describe()
# Out:
#          snow  snowdepth    windgust  severerisk       precip
# count  3701.0     3701.0  3814.00000  413.000000  5496.000000
# mean      0.0        0.0    32.07302   34.067797     4.742413
# std       0.0        0.0    10.68174   17.482037    10.980253
# min       0.0        0.0     8.30000   10.000000     0.000000
# 25%       0.0        0.0    24.80000   30.000000     0.000000
# 50%       0.0        0.0    29.90000   30.000000     0.700000
# 75%       0.0        0.0    37.10000   60.000000     4.700000
# max       0.0        0.0   216.00000   75.000000   227.200000

# %%
drop_cols = ['name','snow', 'snowdepth','sealevelpressure','icon','stations','sunrise','sunset']
df.drop(drop_cols, axis=1, inplace=True)
print("Irrelevant columns droped!")
# Out:
# Irrelevant columns droped!

# %%
df.nunique()
# Out:
# datetime          5496
# tempmax            120
# tempmin             98
# temp               102
# feelslikemax       192
# feelslikemin       155
# feelslike          183
# dew                129
# humidity           465
# precip             367
# precipprob           2
# precipcover         25
# preciptype           1
# windgust           145
# windspeed          268
# winddir           2431
# cloudcover         690
# visibility          77
# solarradiation    1947
# solarenergy        239
# uvindex             11
# severerisk           4
# moonphase           96
# conditions           4
# description         27
# dtype: int64

# %%
check_cols = ['precipprob','preciptype','uvindex','severerisk','conditions']
for col in check_cols:
    print(f"Unique values in '{col}':")
    print(df[col].unique())
    print(f"Counts values in '{col}':")
    print(df[col].count(),'/5496')
    print("-" * 30)
# Out:
# Unique values in 'precipprob':
# [  0. 100.]
# Counts values in 'precipprob':
# 5496 /5496
# ------------------------------
# Unique values in 'preciptype':
# [nan "['rain']"]
# Counts values in 'preciptype':
# 3909 /5496
# ------------------------------
# Unique values in 'uvindex':
# [ 8.  9.  6.  7.  3. 10.  5.  4.  2.  0.  1.]
# Counts values in 'uvindex':
# 5496 /5496
# ------------------------------
# Unique values in 'severerisk':
# [nan 30. 60. 10. 75.]
# Counts values in 'severerisk':
# 413 /5496
# ------------------------------
# Unique values in 'conditions':
# ['Partially cloudy' 'Rain, Partially cloudy' 'Rain, Overcast' 'Clear']
# Counts values in 'conditions':
# 5496 /5496
# ------------------------------

# %%
#fill missing value
df['preciptype'] = df['preciptype'].apply(lambda x: True if x == 'rain' else False) #chuyen ve boolean rain=1 norain=0
df['severerisk']= df['severerisk'].fillna(value=0).infer_objects(copy=False) #fill NaNs bang 0 (no risk)
df['severerisk'] = df['severerisk'].apply(pd.to_numeric, errors='coerce')
    #fill windust with avg seasonal value
df['month_day'] = df['datetime'].dt.strftime('%m-%d')
df['windgust'] = df.groupby('month_day')['windgust'].transform(lambda x: x.fillna(x.mean()))
df.drop(columns=['month_day'], inplace=True)
#add new columns
df['temp_range'] = df['tempmax'] - df['tempmin']
df['month'] = df['datetime'].dt.month

#onehot encoding string columns
df_onehot = pd.get_dummies(df, columns=['conditions'])
df_onehot.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5496 entries, 3653 to 9148
# Data columns (total 30 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   datetime                           5496 non-null   datetime64[ns]
#  1   tempmax                            5496 non-null   float64
#  2   tempmin                            5496 non-null   float64
#  3   temp                               5496 non-null   float64
#  4   feelslikemax                       5496 non-null   float64
#  5   feelslikemin                       5496 non-null   float64
#  6   feelslike                          5496 non-null   float64
#  7   dew                                5496 non-null   float64
#  8   humidity                           5496 non-null   float64
#  9   precip                             5496 non-null   float64
#  10  precipprob                         5496 non-null   float64
#  11  precipcover                        5496 non-null   float64
#  12  preciptype                         5496 non-null   bool
#  13  windgust                           5496 non-null   float64
#  14  windspeed                          5496 non-null   float64
#  15  winddir                            5496 non-null   float64
#  16  cloudcover                         5496 non-null   float64
#  17  visibility                         5496 non-null   float64
#  18  solarradiation                     5496 non-null   float64
#  19  solarenergy                        5496 non-null   float64
#  20  uvindex                            5496 non-null   float64
#  21  severerisk                         5496 non-null   float64
#  22  moonphase                          5496 non-null   float64
#  23  description                        5496 non-null   object
#  24  temp_range                         5496 non-null   float64
#  25  month                              5496 non-null   int32
#  26  conditions_Clear                   5496 non-null   bool
#  27  conditions_Partially cloudy        5496 non-null   bool
#  28  conditions_Rain, Overcast          5496 non-null   bool
#  29  conditions_Rain, Partially cloudy  5496 non-null   bool
# dtypes: bool(5), datetime64[ns](1), float64(22), int32(1), object(1)
# memory usage: 1.1+ MB

# %%
plt.figure(figsize = (20,20))
temp = df_onehot
temp = temp.drop(columns=['preciptype','description'])
sns.heatmap(temp.corr(), annot=True, fmt='.2f', cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()

# %%
plt.figure(figsize=(12,6))
sns.lineplot(x='datetime', y='temp', data=df)
plt.title('Temperature Trend Over Time')
plt.xlabel('Date')
plt.ylabel('Temperature (°C)')
plt.show()

# %%
cols = ['temp', 'humidity', 'windspeed', 'precip']
plt.figure(figsize=(12,8))
for i, col in enumerate(cols, 1):
    plt.subplot(2,2,i)
    sns.histplot(df[col], kde=True)
    plt.title(f'Distribution of {col}')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12,6))
sns.boxplot(x='month', y='temp', data=df)
plt.title('Monthly Temperature Distribution')
plt.xlabel('Month')
plt.ylabel('Temperature (°C)')
plt.show()

# %%
plt.figure(figsize=(12,6))
sns.countplot(y='conditions', data=df, order=df['conditions'].value_counts().index)
plt.title('Frequency of Weather Conditions')
plt.xlabel('Count')
plt.ylabel('Condition')
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(x='datetime', y='winddir', data=df, hue='windspeed')
plt.title('Wind Direction Over Time')
plt.xlabel('Date')
plt.ylabel('Wind Direction (degrees)')
plt.show()
